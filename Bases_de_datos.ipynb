# %% [markdown]
# # Lectura de datos
# ## Base de datos: Almacena, agrupa y codifica estructuras de datos.
#
# ### Información:
# - Numérica
# - Objetos
# - Etiquetas
#
# ### Búsqueda de información (Fuentes):
# - Wikipedia
# - Kaggle
# - INEGI
#
# ### excel, csv, textos (.xlxs, .csv, .txt)

# %%
import pandas as pd

# %%
data = pd.read_csv("charts.csv")

data
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# 2             Lil Nas X & Jack Harlow        3.0          1              14
# 3                        Walker Hayes        4.0          3              19
# 4                          Ed Sheeran        5.0          2              18
# ...                               ...        ...        ...             ...
# 330082                Thurston Harris        NaN         96               1
# 330083                Robert & Johnny        NaN         97               1
# 330084              The Ames Brothers        NaN         98               1
# 330085                 Billy Williams        NaN         99               1
# 330086                Frankie Vaughan        NaN        100               1
#
# [330087 rows x 7 columns]

# %%
data.shape
# Out:
# (330087, 7)

# %%
data.ndim
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  object
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.6+ MB

# %%
data.describe()
# Out:
#                 rank      last-week      peak-rank  weeks-on-board
# count  330087.000000  297775.000000  330087.000000   330087.000000
# mean       50.500929      47.591631      40.970629        9.161785
# std        28.866094      28.054360      29.347481        7.618264
# min         1.000000       1.000000       1.000000        1.000000
# 25%        26.000000      23.000000      13.000000        4.000000
# 50%        51.000000      47.000000      38.000000        7.000000
# 75%        76.000000      72.000000      65.000000       13.000000
# max       100.000000     100.000000     100.000000       90.000000

# %% [markdown]
# ## Slice

# %%
data["song"]
# Out:
# 0                                  Easy On Me
# 1                                        Stay
# 2                               Industry Baby
# 3                                  Fancy Like
# 4                                  Bad Habits
#                          ...
# 330082                          Over And Over
# 330083                       I Believe In You
# 330084                        Little Serenade
# 330085    I'll Get By (As Long As I Have You)
# 330086                                   Judy
# Name: song, Length: 330087, dtype: object

# %%
data[["rank", "song", "artist" ]]
# Out:
#         rank                                 song  \
# 0          1                           Easy On Me
# 1          2                                 Stay
# 2          3                        Industry Baby
# 3          4                           Fancy Like
# 4          5                           Bad Habits
# ...      ...                                  ...
# 330082    96                        Over And Over
# 330083    97                     I Believe In You
# 330084    98                      Little Serenade
# 330085    99  I'll Get By (As Long As I Have You)
# 330086   100                                 Judy
#
#                                artist
# 0                               Adele
# 1       The Kid LAROI & Justin Bieber
# 2             Lil Nas X & Jack Harlow
# 3                        Walker Hayes
# 4                          Ed Sheeran
# ...                               ...
# 330082                Thurston Harris
# 330083                Robert & Johnny
# 330084              The Ames Brothers
# 330085                 Billy Williams
# 330086                Frankie Vaughan
#
# [330087 rows x 3 columns]

# %%
data1 = data.sort_values("weeks-on-board", ascending=False).head(20)
data1
# Out:
#              date  rank             song           artist  last-week  \
# 919    2021-09-04    20  Blinding Lights       The Weeknd       21.0
# 1020   2021-08-28    21  Blinding Lights       The Weeknd       18.0
# 1117   2021-08-21    18  Blinding Lights       The Weeknd       16.0
# 39148  2014-05-10    49      Radioactive  Imagine Dragons       48.0
# 1215   2021-08-14    16  Blinding Lights       The Weeknd       17.0
# 1316   2021-08-07    17  Blinding Lights       The Weeknd       17.0
# 39247  2014-05-03    48      Radioactive  Imagine Dragons       42.0
# 1416   2021-07-31    17  Blinding Lights       The Weeknd       17.0
# 39341  2014-04-26    42      Radioactive  Imagine Dragons       39.0
# 39438  2014-04-19    39      Radioactive  Imagine Dragons       37.0
# 1516   2021-07-24    17  Blinding Lights       The Weeknd       15.0
# 1614   2021-07-17    15  Blinding Lights       The Weeknd       18.0
# 39536  2014-04-12    37      Radioactive  Imagine Dragons       33.0
# 1717   2021-07-10    18  Blinding Lights       The Weeknd       15.0
# 39632  2014-04-05    33      Radioactive  Imagine Dragons       33.0
# 1814   2021-07-03    15  Blinding Lights       The Weeknd       17.0
# 39732  2014-03-29    33      Radioactive  Imagine Dragons       31.0
# 39830  2014-03-22    31      Radioactive  Imagine Dragons       27.0
# 1916   2021-06-26    17  Blinding Lights       The Weeknd       15.0
# 39926  2014-03-15    27      Radioactive  Imagine Dragons       27.0
#
#        peak-rank  weeks-on-board
# 919            1              90
# 1020           1              89
# 1117           1              88
# 39148          3              87
# 1215           1              87
# 1316           1              86
# 39247          3              86
# 1416           1              85
# 39341          3              85
# 39438          3              84
# 1516           1              84
# 1614           1              83
# 39536          3              83
# 1717           1              82
# 39632          3              82
# 1814           1              81
# 39732          3              81
# 39830          3              80
# 1916           1              80
# 39926          3              79

# %%
data.drop(columns=["date"])
# Out:
#         rank                                 song  \
# 0          1                           Easy On Me
# 1          2                                 Stay
# 2          3                        Industry Baby
# 3          4                           Fancy Like
# 4          5                           Bad Habits
# ...      ...                                  ...
# 330082    96                        Over And Over
# 330083    97                     I Believe In You
# 330084    98                      Little Serenade
# 330085    99  I'll Get By (As Long As I Have You)
# 330086   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# 2             Lil Nas X & Jack Harlow        3.0          1              14
# 3                        Walker Hayes        4.0          3              19
# 4                          Ed Sheeran        5.0          2              18
# ...                               ...        ...        ...             ...
# 330082                Thurston Harris        NaN         96               1
# 330083                Robert & Johnny        NaN         97               1
# 330084              The Ames Brothers        NaN         98               1
# 330085                 Billy Williams        NaN         99               1
# 330086                Frankie Vaughan        NaN        100               1
#
# [330087 rows x 6 columns]

# %% [markdown]
# # Ejercicios 1 (Entrega: domingo antes de las 22:00 hrs)
#
# - Realiza un análisis descriptivo de tu base de datos.
#
# - ¿Qué tipo de análisis estadístico deseas analizar?
#
# - Enumera los distintos tipos de objetos que hay en tu base de datos: ¿qué columnas contienen datos numéricos? ¿qué columnas contienen datos categóricos?
#
# - Toma una columna que tenga datos **no nulos** numéricos y da una descripción estadística.
#
# - Elige dos columnas que contengan datos numéricos. A partir de esta subbase de datos, elige los primeros 20 elementos. Realiza nuevamente un análisis descriptivo de esta nueva subbase (escribe brevemente la importancia de tu elección).
#
# - La siguiente celda contiene un ejemplo de cómo realizar un *boxplot*. ¿Qué representa este tipo de gráficas? Realiza una gráfica *boxplot* con la subbase del punto anterior.
#
# - Finalmente, comparte tus conclusiones y tu colab.

# %%
import numpy as np 
import pandas as pd


np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10, 4), columns=['Col1', 'Col2', 'Col3', 'Col4'])
boxplot = df.boxplot(column=['Col1'])

# %%
df["Col1"].describe()
# Out:
# count    10.000000
# mean      0.323001
# std       0.640899
# min      -0.720589
# 25%      -0.133407
# 50%       0.265083
# 75%       0.832852
# max       1.318152
# Name: Col1, dtype: float64

# %%
data1 = data.sort_values("weeks-on-board", ascending=False).head(20)
data1
# Out:
#              date  rank             song           artist  last-week  \
# 919    2021-09-04    20  Blinding Lights       The Weeknd       21.0
# 1020   2021-08-28    21  Blinding Lights       The Weeknd       18.0
# 1117   2021-08-21    18  Blinding Lights       The Weeknd       16.0
# 39148  2014-05-10    49      Radioactive  Imagine Dragons       48.0
# 1215   2021-08-14    16  Blinding Lights       The Weeknd       17.0
# 1316   2021-08-07    17  Blinding Lights       The Weeknd       17.0
# 39247  2014-05-03    48      Radioactive  Imagine Dragons       42.0
# 1416   2021-07-31    17  Blinding Lights       The Weeknd       17.0
# 39341  2014-04-26    42      Radioactive  Imagine Dragons       39.0
# 39438  2014-04-19    39      Radioactive  Imagine Dragons       37.0
# 1516   2021-07-24    17  Blinding Lights       The Weeknd       15.0
# 1614   2021-07-17    15  Blinding Lights       The Weeknd       18.0
# 39536  2014-04-12    37      Radioactive  Imagine Dragons       33.0
# 1717   2021-07-10    18  Blinding Lights       The Weeknd       15.0
# 39632  2014-04-05    33      Radioactive  Imagine Dragons       33.0
# 1814   2021-07-03    15  Blinding Lights       The Weeknd       17.0
# 39732  2014-03-29    33      Radioactive  Imagine Dragons       31.0
# 39830  2014-03-22    31      Radioactive  Imagine Dragons       27.0
# 1916   2021-06-26    17  Blinding Lights       The Weeknd       15.0
# 39926  2014-03-15    27      Radioactive  Imagine Dragons       27.0
#
#        peak-rank  weeks-on-board
# 919            1              90
# 1020           1              89
# 1117           1              88
# 39148          3              87
# 1215           1              87
# 1316           1              86
# 39247          3              86
# 1416           1              85
# 39341          3              85
# 39438          3              84
# 1516           1              84
# 1614           1              83
# 39536          3              83
# 1717           1              82
# 39632          3              82
# 1814           1              81
# 39732          3              81
# 39830          3              80
# 1916           1              80
# 39926          3              79

# %%
data1[data1["weeks-on-board"] >= 85]
# Out:
#              date  rank             song           artist  last-week  \
# 919    2021-09-04    20  Blinding Lights       The Weeknd       21.0
# 1020   2021-08-28    21  Blinding Lights       The Weeknd       18.0
# 1117   2021-08-21    18  Blinding Lights       The Weeknd       16.0
# 39148  2014-05-10    49      Radioactive  Imagine Dragons       48.0
# 1215   2021-08-14    16  Blinding Lights       The Weeknd       17.0
# 1316   2021-08-07    17  Blinding Lights       The Weeknd       17.0
# 39247  2014-05-03    48      Radioactive  Imagine Dragons       42.0
# 1416   2021-07-31    17  Blinding Lights       The Weeknd       17.0
# 39341  2014-04-26    42      Radioactive  Imagine Dragons       39.0
#
#        peak-rank  weeks-on-board
# 919            1              90
# 1020           1              89
# 1117           1              88
# 39148          3              87
# 1215           1              87
# 1316           1              86
# 39247          3              86
# 1416           1              85
# 39341          3              85
